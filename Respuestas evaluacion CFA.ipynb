# %% [markdown]
# ## Fase 1: Exploración y Limpieza
#
# ## Exploración Inicial:
#
# Realiza una exploración inicial de los datos para identificar posibles problemas, como valores
# nulos, atípicos o datos faltantes en las columnas relevantes.
# Utiliza funciones de Pandas para obtener información sobre la estructura de los datos, la
# presencia de valores nulos y estadísticas básicas de las columnas involucradas.
# Une los dos conjuntos de datos de la forma más eficiente.

# %%
import pandas as pd

# %%
df_cfa = pd.read_csv("./files/CFA.csv")
df_cfa.head()
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    Dollar Cost Points Redeemed
# 0                            0
# 1                            0
# 2                            0
# ...

# %%
df_cfa = pd.read_csv("./files/CFA.csv")
df_cfa.head()
# Out:
#    Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0          100018  2017      1               3                        0
# 1          100102  2017      1              10                        4
# 2          100140  2017      1               6                        0
# 3          100214  2017      1               0                        0
# 4          100272  2017      1               0                        0
#
#    Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 0              3      1521               152.0                0
# 1             14      2030               203.0                0
# 2              6      1200               120.0                0
# 3              0         0                 0.0                0
# 4              0         0                 0.0                0
#
#    Dollar Cost Points Redeemed
# 0                            0
# 1                            0
# 2                            0
# ...

# %%
df_cfa.tail()
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 405619          999902  2018     12               0                        0
# 405620          999911  2018     12               0                        0
# 405621          999940  2018     12               3                        0
# 405622          999982  2018     12               0                        0
# 405623          999986  2018     12               0                        0
#
#         Total Flights  Distance  Points Accumulated  Points Redeemed  \
# 405619              0         0                 0.0                0
# 405620              0         0                 0.0                0
# 405621              3      1233               123.0                0
# 405622              0         0                 0.0                0
# 405623              0         0                 0.0                0
#
#         Dollar Cost Points Redeemed
# 405619                            0
# ...

# %%
df_cfa.shape
# Out:
# (405624, 10)

# %%
df_cfa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405624 entries, 0 to 405623
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Loyalty Number               405624 non-null  int64
#  1   Year                         405624 non-null  int64
#  2   Month                        405624 non-null  int64
#  3   Flights Booked               405624 non-null  int64
#  4   Flights with Companions      405624 non-null  int64
#  5   Total Flights                405624 non-null  int64
#  6   Distance                     405624 non-null  int64
#  7   Points Accumulated           405624 non-null  float64
#  8   Points Redeemed              405624 non-null  int64
#  9   Dollar Cost Points Redeemed  405624 non-null  int64
# dtypes: float64(1), int64(9)
# memory usage: 30.9 MB

# %%
df_cfa.isnull().sum()
# Out:
# Loyalty Number                 0
# Year                           0
# Month                          0
# Flights Booked                 0
# Flights with Companions        0
# Total Flights                  0
# Distance                       0
# Points Accumulated             0
# Points Redeemed                0
# Dollar Cost Points Redeemed    0
# dtype: int64

# %%
df_cfa.describe()
# Out:
#        Loyalty Number           Year          Month  Flights Booked  \
# count   405624.000000  405624.000000  405624.000000   405624.000000
# mean    550037.873084    2017.500000       6.500000        4.115052
# std     258935.286969       0.500001       3.452057        5.225518
# min     100018.000000    2017.000000       1.000000        0.000000
# 25%     326961.000000    2017.000000       3.750000        0.000000
# 50%     550834.000000    2017.500000       6.500000        1.000000
# 75%     772194.000000    2018.000000       9.250000        8.000000
# max     999986.000000    2018.000000      12.000000       21.000000
#
#        Flights with Companions  Total Flights       Distance  \
# count            405624.000000  405624.000000  405624.000000
# mean                  1.031805       5.146858    1208.880059
# std                   2.076869       6.521227    1433.155320
# min                   0.000000       0.000000       0.000000
# ...

# %%
df_cfa.describe().T
# Out:
#                                 count           mean            std       min  \
# Loyalty Number               405624.0  550037.873084  258935.286969  100018.0
# Year                         405624.0    2017.500000       0.500001    2017.0
# Month                        405624.0       6.500000       3.452057       1.0
# Flights Booked               405624.0       4.115052       5.225518       0.0
# Flights with Companions      405624.0       1.031805       2.076869       0.0
# Total Flights                405624.0       5.146858       6.521227       0.0
# Distance                     405624.0    1208.880059    1433.155320       0.0
# Points Accumulated           405624.0     123.692721     146.599831       0.0
# Points Redeemed              405624.0      30.696872     125.486049       0.0
# Dollar Cost Points Redeemed  405624.0       2.484503      10.150038       0.0
#
#                                    25%       50%        75%       max
# ...

# %%
df_cfa['Year'].value_counts()
# Out:
# Year
# 2017    202812
# 2018    202812
# Name: count, dtype: int64

# %%
df_cfa.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 405619    False
# 405620    False
# 405621    False
# 405622    False
# 405623    False
# Length: 405624, dtype: bool

# %%
pd.set_option('display.max_columns', None)

# %%
df_cfa
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0               100018  2017      1               3                        0
# 1               100102  2017      1              10                        4
# 2               100140  2017      1               6                        0
# 3               100214  2017      1               0                        0
# 4               100272  2017      1               0                        0
# ...                ...   ...    ...             ...                      ...
# 405619          999902  2018     12               0                        0
# 405620          999911  2018     12               0                        0
# 405621          999940  2018     12               3                        0
# 405622          999982  2018     12               0                        0
# 405623          999986  2018     12               0                        0
#
# ...

# %%
df_cfa.columns
# Out:
# Index(['Loyalty Number', 'Year', 'Month', 'Flights Booked',
#        'Flights with Companions', 'Total Flights', 'Distance',
#        'Points Accumulated', 'Points Redeemed', 'Dollar Cost Points Redeemed'],
#       dtype='object')

# %%
df_cfa.describe()
# Out:
#        Loyalty Number           Year          Month  Flights Booked  \
# count   405624.000000  405624.000000  405624.000000   405624.000000
# mean    550037.873084    2017.500000       6.500000        4.115052
# std     258935.286969       0.500001       3.452057        5.225518
# min     100018.000000    2017.000000       1.000000        0.000000
# 25%     326961.000000    2017.000000       3.750000        0.000000
# 50%     550834.000000    2017.500000       6.500000        1.000000
# 75%     772194.000000    2018.000000       9.250000        8.000000
# max     999986.000000    2018.000000      12.000000       21.000000
#
#        Flights with Companions  Total Flights       Distance  \
# count            405624.000000  405624.000000  405624.000000
# mean                  1.031805       5.146858    1208.880059
# std                   2.076869       6.521227    1433.155320
# min                   0.000000       0.000000       0.000000
# ...

# %%
df_cfa
# Out:
#         Loyalty Number  Year  Month  Flights Booked  Flights with Companions  \
# 0               100018  2017      1               3                        0
# 1               100102  2017      1              10                        4
# 2               100140  2017      1               6                        0
# 3               100214  2017      1               0                        0
# 4               100272  2017      1               0                        0
# ...                ...   ...    ...             ...                      ...
# 405619          999902  2018     12               0                        0
# 405620          999911  2018     12               0                        0
# 405621          999940  2018     12               3                        0
# 405622          999982  2018     12               0                        0
# 405623          999986  2018     12               0                        0
#
# ...

# %% [markdown]
# ## Limpieza de Datos:
#
# Elimina o trata los valores nulos, si los hay, en las columnas clave para asegurar que los datos
# estén completos.
# Verifica la consistencia y corrección de los datos para asegurarte de que los datos se
# presenten de forma coherente.
# Realiza cualquier ajuste o conversión necesaria en las columnas (por ejemplo, cambiar tipos de
# datos) para garantizar la adecuación de los datos para el análisis estadístico.

# %%
df_cfa.isnull().sum()
# Out:
# Loyalty Number                 0
# Year                           0
# Month                          0
# Flights Booked                 0
# Flights with Companions        0
# Total Flights                  0
# Distance                       0
# Points Accumulated             0
# Points Redeemed                0
# Dollar Cost Points Redeemed    0
# dtype: int64

# %% [markdown]
# ## Pendiente tarea: pasar float a int

# %% [markdown]
# ## Fase 2: Análisis Estadístico
#
# 1. Análisis de variables numéricas:
# 1.1. Estadísticas descriptivas (media, mediana, moda, desviación estándar, etc.) de las variables
# numéricas relevantes.
# 1.2. Identificación de valores atípicos en las variables numéricas.
# 1.3. Análisis de correlación entre variables numéricas.
# 2. Análisis de variables categóricas:
# 2.1. Distribución de frecuencias de las variables categóricas relevantes.
#
# En todos los ejercicios, no te quedes solo en el “número”: añade siempre una breve interpretación en
# lenguaje natural, como lo haría un analista al presentar resultados a un equipo no técnico.

# %% [markdown]
# # Pendiente en CLH verificar la correlacion y arreglar los salarios negativos

# %% [markdown]
# ## Fase 3: Visualización
#
# Usando las herramientas de visualización que has aprendido durante este módulo, contesta a las siguientes
# preguntas usando la mejor gráfica que consideres:
#
# 1. ¿Cómo se distribuye la cantidad de vuelos reservados por mes durante el año?
# 2. ¿Existe una relación entre la distancia de los vuelos y los puntos acumulados por los cliente?
# 3. ¿Cuál es la distribución de los clientes por provincia o estado?
# 4. ¿Cómo se compara el salario promedio entre los diferentes niveles educativos de los clientes?
# 5. ¿Cuál es la proporción de clientes con diferentes tipos de tarjetas de fidelidad?
# 6. ¿Cómo se distribuyen los clientes según su estado civil y género?
#
# En todos los ejercicios, no te quedes solo con la representación visual: añade siempre una breve
# interpretación en lenguaje natural, como lo haría un analista al presentar resultados a un equipo no
# técnico.

# %% [markdown]
# ## Fase 4: Evaluación de Diferencias en Reservas de Vuelos por Nivel Educativo
#
# Utilizando un conjunto de datos que hemos compartido, se busca evaluar si existen diferencias
# significativas en el número de vuelos reservados según el nivel educativo de los clientes. Para ello, los
# pasos que deberás seguir son:
#
# 1. Preparación de Datos: Filtra el conjunto de datos para incluir únicamente las columnas relevantes:
# 'Flights Booked' y 'Education'.
# 2. Análisis Descriptivo: Agrupa los datos por nivel educativo y calcula estadísticas descriptivas
# básicas (como el promedio, la desviación estándar) del número de vuelos reservados para cada
# grupo.

# %%
import pandas as pd
df_clh = pd.read_csv("./files/CLH.csv", index_col = "Loyalty Number")

# %%
df_clh.head()
# Out:
#                Country          Province       City Postal Code  Gender  \
# Loyalty Number
# 480934          Canada           Ontario    Toronto     M2Z 4K1  Female
# 549612          Canada           Alberta   Edmonton     T3G 6Y6    Male
# 429460          Canada  British Columbia  Vancouver     V6E 3D9    Male
# 608370          Canada           Ontario    Toronto     P1W 1K4    Male
# 530508          Canada            Quebec       Hull     J8Y 3Z5    Male
#
#                Education    Salary Marital Status Loyalty Card      CLV  \
# Loyalty Number
# 480934          Bachelor   83236.0        Married         Star  3839.14
# 549612           College       NaN       Divorced         Star  3839.61
# 429460           College       NaN         Single         Star  3839.75
# 608370           College       NaN         Single         Star  3839.75
# 530508          Bachelor  103495.0        Married         Star  3842.79
#
# ...

# %%
import pandas as pd
df_cfa_1 = pd.read_csv("./files/CLH.csv", index_col = "Loyalty Number")

# %%
df_cfa_1.head()
# Out:
#                Country          Province       City Postal Code  Gender  \
# Loyalty Number
# 480934          Canada           Ontario    Toronto     M2Z 4K1  Female
# 549612          Canada           Alberta   Edmonton     T3G 6Y6    Male
# 429460          Canada  British Columbia  Vancouver     V6E 3D9    Male
# 608370          Canada           Ontario    Toronto     P1W 1K4    Male
# 530508          Canada            Quebec       Hull     J8Y 3Z5    Male
#
#                Education    Salary Marital Status Loyalty Card      CLV  \
# Loyalty Number
# 480934          Bachelor   83236.0        Married         Star  3839.14
# 549612           College       NaN       Divorced         Star  3839.61
# 429460           College       NaN         Single         Star  3839.75
# 608370           College       NaN         Single         Star  3839.75
# 530508          Bachelor  103495.0        Married         Star  3842.79
#
# ...

# %%
df_concat1 = pd.concat([df_cfa_1, df_clh], axis=1)
#axis=1: Concatena los DataFrames por columnas (horizontal). Los DataFrames se colocan uno al lado del otro, no uno debajo del otro.
#Columnas duplicadas: Si los DataFrames tienen columnas con el mismo nombre, aparecerán repetidas en el resultado.
# Índices: Las filas se alinean según el índice. Si los índices no coinciden, se rellenan con NaN.
# Tamaño: El DataFrame resultante tendrá tantas filas como el índice más largo y la suma de todas las columnas.
df_concat1.head()
# Out:
#                Country          Province       City Postal Code  Gender  \
# Loyalty Number
# 480934          Canada           Ontario    Toronto     M2Z 4K1  Female
# 549612          Canada           Alberta   Edmonton     T3G 6Y6    Male
# 429460          Canada  British Columbia  Vancouver     V6E 3D9    Male
# 608370          Canada           Ontario    Toronto     P1W 1K4    Male
# 530508          Canada            Quebec       Hull     J8Y 3Z5    Male
#
#                Education    Salary  Marital Status  Loyalty Card      CLV  \
# Loyalty Number
# 480934          Bachelor   83236.0         Married          Star  3839.14
# 549612           College       NaN        Divorced          Star  3839.61
# 429460           College       NaN          Single          Star  3839.75
# 608370           College       NaN          Single          Star  3839.75
# 530508          Bachelor  103495.0         Married          Star  3842.79
#
# ...

# %%
df_concat1.shape
# Out:
# (16737, 30)

# %%
df_concat2 = pd.concat([df_cfa_1, df_clh])
#axis=1: Concatena los DataFrames por columnas (horizontal). Los DataFrames se colocan uno al lado del otro, no uno debajo del otro.
#Columnas duplicadas: Si los DataFrames tienen columnas con el mismo nombre, aparecerán repetidas en el resultado.
# Índices: Las filas se alinean según el índice. Si los índices no coinciden, se rellenan con NaN.
# Tamaño: El DataFrame resultante tendrá tantas filas como el índice más largo y la suma de todas las columnas.
df_concat2.head()
# Out:
#                Country          Province       City Postal Code  Gender  \
# Loyalty Number
# 480934          Canada           Ontario    Toronto     M2Z 4K1  Female
# 549612          Canada           Alberta   Edmonton     T3G 6Y6    Male
# 429460          Canada  British Columbia  Vancouver     V6E 3D9    Male
# 608370          Canada           Ontario    Toronto     P1W 1K4    Male
# 530508          Canada            Quebec       Hull     J8Y 3Z5    Male
#
#                Education    Salary Marital Status Loyalty Card      CLV  \
# Loyalty Number
# 480934          Bachelor   83236.0        Married         Star  3839.14
# 549612           College       NaN       Divorced         Star  3839.61
# 429460           College       NaN         Single         Star  3839.75
# 608370           College       NaN         Single         Star  3839.75
# 530508          Bachelor  103495.0        Married         Star  3842.79
#
# ...

# %%
df_concat2.shape
# Out:
# (33474, 15)
